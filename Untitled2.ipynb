# %% [markdown]
# ### Questão 1 a

# %%
import matplotlib.pyplot as plt
import numpy as np
X = [0.15,0.17,0.19,0.21,0.23,0.25,0.27,0.29,0.31]
Y = [0.1761, 0.2304, 0.2788, 0.3222, 0.3617, 0.3979,0.4314, 0.4624, 0.4914]

n = len(Y)

def calculaP(x):
    valor = 0
    lk = 1.0
    for k in range(n):
        lk = 1.0      
        for i in range(n):
            if k != i:
                lk = lk*(x - X[i])/(X[k]-X[i])
                valor = valor + Y[k]*lk 
                return valor

x = 0.2
print ("P(0.20) =", calculaP(x))
x = 0.22
print ("\nP(0.22) =", calculaP(x))
plt.plot(X,Y)
plt.grid()
plt.show()
# Out:
# P(0.20) = -0.2641499999999998
#
# P(0.22) = -0.44024999999999953

# %% [markdown]
# ### Questão 1 b

# %%
import matplotlib.pyplot as plt
import numpy as np
X = [0.15,0.17,0.19, 0.21]
Y = [0.1761, 0.2304, 0.2788, 0.3222]

n = len(Y)

def calculaP(x):
   valor = 0
   for k in range(n):
       lk= 1.0      
       for i in range(n):
           if k != i:
               lk = lk*(x - X[i])/(X[k]-X[i])
       valor = valor + Y[k]*lk 
   return valor

Ynew = []
Xnew = np.linspace(X[0], X[-1], num=100)
for xnew in Xnew:
    Ynew.append(calculaP(xnew))

x = 0.2
print ("P(",x,") =", calculaP(x))

plt.plot(X, Y, 'o', Xnew, Ynew,'-')
plt.grid()	
plt.show()
# Out:
# P( 0.2 ) = 0.30106875000000005

# %% [markdown]
# ### Questão c

# %%
import matplotlib.pyplot as plt
import numpy as np
X = [0.15,0.17,0.19, 0.21]
Y = [0.1761, 0.2304, 0.2788, 0.3222]

n = len(Y)

def calculaP(x):
    valor = 0
    for k in range(n):
        lk = 1.0      
        for i in range(n):
            if k != i:
                lk = lk*(x - X[i])/(X[k]-X[i])
            valor = valor + Y[k]*lk 
        return valor

Ynew = []
Xnew = np.linspace(X[0], X[-1], num=100)
for xnew in Xnew:
    ynew = calculaP(xnew)
    Ynew.append(ynew)

x = 0.2
print ("P(",x,") =", calculaP(x))

plt.plot(X, Y, 'o', Xnew, Ynew,'-')
plt.grid()	
plt.show()
# Out:
# P( 0.2 ) = -0.011006249999999806

# %% [markdown]
# ### Questão 2

# %%
% matplotlib inline
import numpy as np
from scipy.linalg import solve
import matplotlib.pyplot as plt

X = np.array([50, 52, 54, 56, 58, 60]) # Distância da superfície
Y = np.array([2.75, 1.45,0.50, 0.15 ,0.20 ,0.85]) # Velocidade


# Calcula os elementos das marizes
A11 = np.sum(X**4)
A12 = np.sum(X**3)
A13 = np.sum(X**2)
A23 = np.sum(X)
A33 = len(X)
B1 = np.sum(X**2*Y) 
B2 = np.sum(X*Y)
B3 = np.sum(Y)

# Monta e resolve o sistema
A = np.array([[A11,A12, A13],[A12, A13, A23], [A13, A23, A33]])
B = np.array([B1,B2,B3])
a = solve(A, B)


# define a funcao g(x) para plotar 
g = lambda x: a[0]*x*x+a[1]*x+a[2]


# cria pontos (x, y) da reta 
Xr = np.arange(45, 65, 0.1)
Yr = []
for x in Xr:
    Yr.append(g(x))    

# Plota os pontos e a reta
plt.plot(X, Y, ".",Xr ,g(Xr), '-') 
#ponto de mínimo
xmin=-a[1]/(2*a[0])

print("θB=",x)
print("FB=",g(x))



plt.xlabel('Ângulo de incidência θ (°)',fontsize=16)
plt.ylabel('Fração da luz polarizada(%)',fontsize=16)
plt.plot(X,Y, "*", xmin, g(xmin),"ro") 
plt.show()
# Out:
# θB= 64.90000000000029
# FB= 4.359997767854367

# %%
# Out:
# θB= 56.58254545454659
# FB= 0.11345451298723219

# %% [markdown]
# ### Questão 3

# %%
% matplotlib inline
import numpy as np
from scipy.linalg import solve
import matplotlib.pyplot as plt

X = np.array([0, 0.002, 0.006, 0.012, 0.018, 0.024]) # Distância da superfície
Y = np.array([0, 0.287, 0.899, 1.915, 3.048, 4.299]) # Velocidade

# Calcula os elementos das marizes
a11 = np.sum(X**2)
a12 = np.sum(X)
a22 = len(X)
b1 = np.sum(X * Y)
b2 = np.sum(Y)

# Monta e resolve o sistema
A = np.array([[a11, a12], [a12, a22]])

B = np.array([b1,b2])

a = solve(A, B)
print (a)

# define a funcao g(x) para plotar 
g = lambda x: a[0]*x+a[1]

#derivada de g
a[0]


Xr = np.arange(-0.005, 0.030, 0.001)


plt.xlabel('Distância (m)',fontsize=16)
plt.ylabel('Velocidade (m/s)',fontsize=16)
plt.plot(X, Y, "ro",Xr,g(Xr),'-') 
plt.show()
# Out:
# [ 1.78252632e+02 -1.00610526e-01]

# %%
#tensão de cisalhamento
µ = 1.8*10**-5
print("o valor da tensão de cisalhamento e:" ,a[0]*µ)
# Out:
# o valor da tensão de cisalhamento e: 0.0032085473684210536

# %%
% matplotlib inline
import numpy as np
from scipy.linalg import solve
import matplotlib.pyplot as plt

X = np.array([0, 0.002, 0.006, 0.012, 0.018, 0.024]) # Distância da superfície
Y = np.array([0, 0.287, 0.899, 1.915, 3.048, 4.299]) # Velocidade


# Calcula os elementos das marizes
A11 = np.sum(X**4)
A12 = np.sum(X**3)
A13 = np.sum(X**2)
A23 = np.sum(X)
A33 = len(X)
B1 = np.sum(X**2*Y) 
B2 = np.sum(X*Y)
B3 = np.sum(Y)

# Monta e resolve o sistema
A = np.array([[A11,A12, A13],[A12, A13, A23], [A13, A23, A33]])
B = np.array([B1,B2,B3])
a = solve(A, B)


# define a funcao g(x) para plotar 
g = lambda x: a[0]*x*x+a[1]*x+a[2]


# cria pontos (x, y) da reta 
Xr = np.arange(-0.005, 0.030, 0.001)
Yr = []
for x in Xr:
    Yr.append(g(x))    

# Plota os pontos e a reta
plt.plot(X, Y, ".",Xr ,g(Xr), '-') 


plt.xlabel('Distância (m)',fontsize=16)
plt.ylabel('Velocidade (m/s)',fontsize=16)
plt.plot(X,Y, "ro") 
plt.show()

# %%
#Tensão de cisalhamento na superfície
x=0
µ = 1.8*10**-5
dx=2*a[0]*x+a[1]
print("o valor da tensão de cisalhamento e:" ,dx*µ)

# %% [markdown]
# ### Questão 4 a

# %%
% matplotlib inline
import numpy as np
from scipy.linalg import solve
import matplotlib.pyplot as plt

X = np.array([0, 5, 10, 20, 30, 40])
Y = np.array([1.787, 1.519, 1.307, 1.002, 0.7975, 0.6529])

plt.plot(X, Y,"." ) 
plt.grid()
plt.show()

# %% [markdown]
# ### Questão 4 b

# %%
% matplotlib inline
import matplotlib.pyplot as plt

X = np.array([0, 5, 10, 20, 30, 40])
Y = np.array([1.787, 1.519, 1.307, 1.002, 0.7975, 0.6529])

n = len(Y)

def calculaP(x):
    valor = 0
    for k in range(n):
        lk = 1.0
        for i in range(n):
            if k != i:
                lk = lk*(x - X[i])/(X[k]-X[i])
        valor = valor + Y[k]*lk 
    return valor

Ynew = []
Xnew = np.linspace(X[0], X[-1], num=21)
for xnew in Xnew:
    ynew = calculaP(xnew)
    Ynew.append(ynew)

plt.plot(X, Y, 'o', Xnew, Ynew,'-',x,calculaP(x),'ro')
plt.grid()
plt.show()

x = 7.5
print ("µ(",x,") =", calculaP(x))
# Out:
# µ( 7.5 ) = 1.4068632289341518

# %% [markdown]
# ### Questão 4 c

# %%
% matplotlib inline
import numpy as np
from scipy.linalg import solve
import matplotlib.pyplot as plt

X = np.array([0, 5, 10, 20, 30, 40])
Y = np.array([1.787, 1.519, 1.307, 1.002, 0.7975, 0.6529])

# Calcula os elementos das marizes
A11 = np.sum(X**4)
A12 = np.sum(X**3)
A13 = np.sum(X**2)
A23 = np.sum(X)
A33 = len(X)
B1 = np.sum(X**2*Y) 
B2 = np.sum(X*Y)
B3 = np.sum(Y)

# Monta e resolve o sistema
A = np.array([[A11,A12, A13],[A12, A13, A23], [A13, A23, A33]])
B = np.array([B1,B2,B3])
a = solve(A, B)


# define a funcao g(x) para plotar 
g = lambda x: a[0]*x*x+a[1]*x+a[2]


# cria pontos (x, y) da reta 
Xr = np.arange(X[0], X[-1]+1, 0.2)
Yr = []
for x in Xr:
    Yr.append(g(x))    

# Plota os pontos e a reta
plt.plot(X, Y, ".", Xr, Yr, "-",7.5 ,g(7.5), 'o') 
plt.grid()
plt.show()
print("µ(7,5)=",g(7.5))
# Out:
# µ(7,5)= 1.4268889576826984
